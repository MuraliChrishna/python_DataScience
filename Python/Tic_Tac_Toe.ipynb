# %%
def board_demo():
    print('This is a Demo indexes of the blocks in the game')
    print('     |     |     ')
    print('  1  |  2  |  3  ')
    print('     |     |     ')
    print('-----------------')
    print('     |     |     ')
    print('  4  |  5  |  6  ')
    print('     |     |     ')
    print('-----------------')
    print('     |     |     ')
    print('  7  |  8  |  9  ')
    print('     |     |     ')
    
def player_name():
    print('Enter player Name: ')
    return input()

def player_symbol(x):
    imarker =''
    print(f'Enter your Symbol {x} : ')
    imarker = input().upper()
    while imarker != 'X' and imarker != 'O':
        print('Please enter either X or O')
        imarker = input(f'{x} choose eithe X or O').upper()
    else:
        return imarker
    
def player_choice(player_name, symbol, list1):
    print(f'{player_name} please enter the index you want your symbol on')
    choice_of_index = int(input())
    while choice_of_index < 1 or 9< choice_of_index:
    #while choice_of_index not in range(1,10):
        print('please enter index between 1 and 9')
        choice_of_index = int(input())
    else:
        while list1[choice_of_index] == 'X' or list1[choice_of_index] == 'O':
            print('Other player also chose this place')
            choice_of_index = int(input())
        else:
            list1[choice_of_index] = symbol
 #           print('Let"s start the game')
            print('     |     |     ')
            print(f'  {list1[1]}  |  {list1[2]}  |  {list1[3]}  ')
            print('     |     |     ')
            print('-----------------')
            print('     |     |     ')
            print(f'  {list1[4]}  |  {list1[5]}  |  {list1[6]}  ')
            print('     |     |     ')
            print('-----------------')
            print('     |     |     ')
            print(f'  {list1[7]}  |  {list1[8]}  |  {list1[9]}  ')
            print('     |     |     ')
            win_check = winner(list1, symbol)
            while win_check:
                print(f'{player_name} Won the game')
                print('Do you want to play again please enter Yes or No')
                yes_no = input().upper()
                while yes_no != 'YES' and yes_no != 'NO':
                    print('Please enter YES or NO')
                    yes_no = input().upper()
                else :
                    if yes_no == 'YES':
                        list2 = ['null',' ',' ', ' ',' ',' ',' ',' ',' ',' '] 
                        player_choice(player_name, symbol, list2)
                    else:
                        print('Thank You! Have a Good day')
                return True
        
def winner(lsit, symbol):
    if (lsit[1] == lsit[2] == lsit[3] == symbol) or (lsit[4] == lsit[5] == lsit[6] == symbol) or (lsit[7] == lsit[8] == lsit[9] == symbol) or (lsit[1] == lsit[4] ==lsit[7] == symbol) or  (lsit[2] == lsit[5] ==lsit[8] == symbol) or  (lsit[3] == lsit[6] ==lsit[9] == symbol) or (lsit[1] == lsit[5] ==lsit[9] == symbol) or  (lsit[3] == lsit[5] ==lsit[7] == symbol):
        return True
         
def game():
    list1 = ['null',' ',' ', ' ',' ',' ',' ',' ',' ',' ']  
    stat = False
    board_demo()
    player_one = player_name()
    player_two = player_name()
    player_one_symbol = player_symbol(player_one).upper()
    if player_one_symbol == 'X':
        player_two_symbol = 'O'
    else :
        player_two_symbol = 'X'
    print(player_one+' Your symbol is '+player_one_symbol)
    print(player_two+' Your symbol is '+player_two_symbol)
    for i in range(1,10):
        if i%2 != 0:
            stat = player_choice(player_one, player_one_symbol, list1)
            if stat == True:
                break        
        else:
            stat = player_choice(player_two, player_two_symbol, list1)
            if stat == True:
                break

# %%
game()

#player_choice('murali', 'X')
# Out:
# This is a Demo indexes of the blocks in the game
#      |     |
#   1  |  2  |  3
#      |     |
# -----------------
#      |     |
#   4  |  5  |  6
#      |     |
# -----------------
#      |     |
#   7  |  8  |  9
#      |     |
# Enter player Name:
# murali
# Enter player Name:
# krishna
# Enter your Symbol murali :
# x
# murali Your symbol is X
# krishna Your symbol is O
# murali please enter the index you want your symbol on
# 1
#      |     |
#   X  |     |
#      |     |
# -----------------
#      |     |
#      |     |
#      |     |
# -----------------
#      |     |
#      |     |
#      |     |
# krishna please enter the index you want your symbol on
# 2
#      |     |
#   X  |  O  |
#      |     |
# -----------------
#      |     |
#      |     |
#      |     |
# -----------------
#      |     |
#      |     |
#      |     |
# murali please enter the index you want your symbol on
# 3
#      |     |
#   X  |  O  |  X
#      |     |
# -----------------
#      |     |
# ...

# %%
player_choice('murali', 'X')

# %%
def layout():
    print('Let"s start the game')
    print('     |     |     ')
    print('     |     |     ')
    print('     |     |     ')
    print('-----------------')
    print('     |     |     ')
    print('     |     |     ')
    print('     |     |     ')
    print('-----------------')
    print('     |     |     ')
    print('     |     |     ')
    print('     |     |     ')
def result():
    print('Won the game')
