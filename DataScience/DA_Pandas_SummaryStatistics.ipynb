# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
matt = np.array([[1,2,np.nan], [np.nan,3,4]])

# %%
data_frame = DataFrame(matt, index=['A','B'], columns= ['one','two','three'])

# %%
data_frame

# %%
data_frame.sum()

# %%
data_frame.sum(axis=1)

# %%
data_frame.min()
#finds minimum value in each column

# %%
data_frame.idxmin()
# minium value of each column but prints index

# %%
data_frame.idxmax()

# %%
data_frame

# %%
data_frame.cumsum()
# cum sum will return colum sum going down 
# for diff go down and look at second column

# %%
data_frame.describe()

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('xGbpuFNR1ME')

# %%
YouTubeVideo('4EXNedimDMs')

# %%
#from pandas_datareader import data, wb
from pandas_datareader import data, wb
import datetime

# %%
prices = data.get_data_yahoo(['CVX','XOM','BP'],
                               start = datetime.datetime(2010,1,1),
                              end = datetime.datetime(2018,1,1))['Adj Close']
prices.head()
# Out:
# Symbols            BP        CVX        XOM
# Date
# 2010-01-04  37.413563  57.221714  52.448120
# 2010-01-05  37.679211  57.627045  52.652916
# 2010-01-06  37.875301  57.634270  53.107986
# 2010-01-07  37.862652  57.417149  52.941124
# 2010-01-08  37.951195  57.518463  52.728752

# %%
prices
# Out:
# Symbols            BP         CVX        XOM
# Date
# 2010-01-04  37.413563   57.221714  52.448120
# 2010-01-05  37.679211   57.627045  52.652916
# 2010-01-06  37.875301   57.634270  53.107986
# 2010-01-07  37.862652   57.417149  52.941124
# 2010-01-08  37.951195   57.518463  52.728752
# 2010-01-11  39.146667   58.538975  53.320362
# 2010-01-12  38.899979   58.198822  53.054893
# 2010-01-13  39.089729   57.757294  52.842525
# 2010-01-14  39.045464   57.576359  52.850094
# 2010-01-15  38.988522   57.344749  52.417782
# 2010-01-19  39.418648   57.670456  52.539131
# 2010-01-20  38.621666   56.563080  51.598629
# 2010-01-21  37.679211   55.180656  50.589870
# 2010-01-22  36.603931   53.986435  50.134804
# 2010-01-25  37.034050   53.957504  49.945179
# 2010-01-26  36.996098   53.667984  49.998264
# 2010-01-27  36.724121   53.342281  49.710049
# 2010-01-28  36.262375   53.009338  49.270145
# 2010-01-29  35.497017   52.198715  48.868149
# 2010-02-01  36.199123   53.255417  50.195473
# ...

# %%
volume = data.get_data_yahoo(['CVX','XOM','BP'], start = datetime.datetime(2010,1,1),
                            end = datetime.datetime(2018, 1,1))['Volume']

# %%
volume.head()
# Out:
# Symbols            BP         CVX         XOM
# Date
# 2010-01-04  3956100.0  10173800.0  27809100.0
# 2010-01-05  4109600.0  10593700.0  30174700.0
# 2010-01-06  6227900.0  11014600.0  35044700.0
# 2010-01-07  4431300.0   9626900.0  27192100.0
# 2010-01-08  3786100.0   5624300.0  24891800.0

# %%
rets = prices.pct_change()

# %%
rets
# Out:
# Symbols           BP       CVX       XOM
# Date
# 2010-01-04       NaN       NaN       NaN
# 2010-01-05  0.007100  0.007084  0.003905
# 2010-01-06  0.005204  0.000125  0.008643
# 2010-01-07 -0.000334 -0.003767 -0.003142
# 2010-01-08  0.002339  0.001765 -0.004011
# 2010-01-11  0.031500  0.017742  0.011220
# 2010-01-12 -0.006302 -0.005811 -0.004979
# 2010-01-13  0.004878 -0.007587 -0.004003
# 2010-01-14 -0.001132 -0.003133  0.000143
# 2010-01-15 -0.001458 -0.004023 -0.008180
# 2010-01-19  0.011032  0.005680  0.002315
# 2010-01-20 -0.020218 -0.019202 -0.017901
# 2010-01-21 -0.024402 -0.024440 -0.019550
# 2010-01-22 -0.028538 -0.021642 -0.008995
# 2010-01-25  0.011751 -0.000536 -0.003782
# 2010-01-26 -0.001025 -0.005366  0.001063
# 2010-01-27 -0.007351 -0.006069 -0.005765
# 2010-01-28 -0.012573 -0.006242 -0.008849
# 2010-01-29 -0.021106 -0.015292 -0.008159
# 2010-02-01  0.019779  0.020244  0.027161
# 2010-02-02 -0.030928  0.011824  0.011786
# 2010-02-03 -0.005229 -0.016655 -0.005376
# ...

# %%
# correlation of the stocks

# %%
corr = rets.corr

# %%
corr
# Out:
# <bound method DataFrame.corr of Symbols           BP       CVX       XOM
# Date
# 2010-01-04       NaN       NaN       NaN
# 2010-01-05  0.007100  0.007084  0.003905
# 2010-01-06  0.005204  0.000125  0.008643
# 2010-01-07 -0.000334 -0.003767 -0.003142
# 2010-01-08  0.002339  0.001765 -0.004011
# 2010-01-11  0.031500  0.017742  0.011220
# 2010-01-12 -0.006302 -0.005811 -0.004979
# 2010-01-13  0.004878 -0.007587 -0.004003
# 2010-01-14 -0.001132 -0.003133  0.000143
# 2010-01-15 -0.001458 -0.004023 -0.008180
# 2010-01-19  0.011032  0.005680  0.002315
# 2010-01-20 -0.020218 -0.019202 -0.017901
# 2010-01-21 -0.024402 -0.024440 -0.019550
# 2010-01-22 -0.028538 -0.021642 -0.008995
# 2010-01-25  0.011751 -0.000536 -0.003782
# 2010-01-26 -0.001025 -0.005366  0.001063
# 2010-01-27 -0.007351 -0.006069 -0.005765
# 2010-01-28 -0.012573 -0.006242 -0.008849
# 2010-01-29 -0.021106 -0.015292 -0.008159
# 2010-02-01  0.019779  0.020244  0.027161
# 2010-02-02 -0.030928  0.011824  0.011786
# ...

# %%
# %matplotlib inline
prices.plot()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(rets.corr())

# %%
ser1 = Series(['w','w','x','y','z','w','x','y','x','a'])

# %%
ser1.unique()
# Out:
# array(['w', 'x', 'y', 'z', 'a'], dtype=object)

# %%
ser1.value_counts()
# Out:
# w    3
# x    3
# y    2
# a    1
# z    1
# dtype: int64
